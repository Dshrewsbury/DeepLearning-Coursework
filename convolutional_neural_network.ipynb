# %% [markdown]
# # Convolutional Neural Network

# %% [markdown]
# ### Importing the libraries

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# %cd gdrive
# %cd My Drive
# %cd Colab\ Notebooks
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive
# /content/gdrive
# /content/gdrive/My Drive
# /content/gdrive/My Drive/Colab Notebooks

# %%
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator
# Out:
# Using TensorFlow backend.

# %%
tf.__version__
# Out:
# '2.2.0'

# %% [markdown]
# ## Part 1 - Data Preprocessing

# %% [markdown]
# ### Preprocessing the Training set

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)
training_set = train_datagen.flow_from_directory('dataset/training_set',
                                                 target_size = (64, 64),
                                                 batch_size = 32,
                                                 class_mode = 'binary')
# Out:
# Found 8000 images belonging to 2 classes.

# %% [markdown]
# ### Preprocessing the Test set

# %%
test_datagen = ImageDataGenerator(rescale = 1./255)
test_set = test_datagen.flow_from_directory('dataset/test_set',
                                            target_size = (64, 64),
                                            batch_size = 32,
                                            class_mode = 'binary')
# Out:
# Found 2000 images belonging to 2 classes.

# %% [markdown]
# ## Part 2 - Building the CNN

# %% [markdown]
# ### Initialising the CNN

# %%
cnn = tf.keras.models.Sequential()

# %% [markdown]
# ### Step 1 - Convolution

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu', input_shape=[64, 64, 3]))

# %% [markdown]
# ### Step 2 - Pooling

# %%
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# %% [markdown]
# ### Adding a second convolutional layer

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# %% [markdown]
# ### Step 3 - Flattening

# %%
cnn.add(tf.keras.layers.Flatten())

# %% [markdown]
# ### Step 4 - Full Connection

# %%
cnn.add(tf.keras.layers.Dense(units=128, activation='relu'))

# %% [markdown]
# ### Step 5 - Output Layer

# %%
cnn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# %% [markdown]
# ## Part 3 - Training the CNN

# %% [markdown]
# ### Compiling the CNN

# %%
cnn.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %% [markdown]
# ### Training the CNN on the Training set and evaluating it on the Test set

# %%
cnn.fit(x = training_set, validation_data = test_set, epochs = 25)
# Out:
# Epoch 1/25
# 250/250 [==============================] - 1503s 6s/step - loss: 0.6659 - accuracy: 0.5925 - val_loss: 0.6103 - val_accuracy: 0.6875
# Epoch 2/25
# 250/250 [==============================] - 83s 332ms/step - loss: 0.6234 - accuracy: 0.6529 - val_loss: 0.5983 - val_accuracy: 0.6805
# Epoch 3/25
# 250/250 [==============================] - 82s 329ms/step - loss: 0.5697 - accuracy: 0.7082 - val_loss: 0.5535 - val_accuracy: 0.7315
# Epoch 4/25
# 250/250 [==============================] - 86s 342ms/step - loss: 0.5363 - accuracy: 0.7237 - val_loss: 0.5228 - val_accuracy: 0.7475
# Epoch 5/25
# 250/250 [==============================] - 83s 332ms/step - loss: 0.5158 - accuracy: 0.7455 - val_loss: 0.5032 - val_accuracy: 0.7530
# Epoch 6/25
# 250/250 [==============================] - 82s 330ms/step - loss: 0.4890 - accuracy: 0.7581 - val_loss: 0.5232 - val_accuracy: 0.7495
# Epoch 7/25
# 250/250 [==============================] - 83s 330ms/step - loss: 0.4772 - accuracy: 0.7692 - val_loss: 0.4982 - val_accuracy: 0.7570
# Epoch 8/25
# 250/250 [==============================] - 85s 341ms/step - loss: 0.4643 - accuracy: 0.7749 - val_loss: 0.4953 - val_accuracy: 0.7640
# Epoch 9/25
# 250/250 [==============================] - 83s 330ms/step - loss: 0.4453 - accuracy: 0.7933 - val_loss: 0.4644 - val_accuracy: 0.7880
# Epoch 10/25
# 250/250 [==============================] - 83s 331ms/step - loss: 0.4263 - accuracy: 0.7999 - val_loss: 0.4671 - val_accuracy: 0.7895
# Epoch 11/25
# 250/250 [==============================] - 83s 332ms/step - loss: 0.4083 - accuracy: 0.8130 - val_loss: 0.4569 - val_accuracy: 0.7910
# Epoch 12/25
# 250/250 [==============================] - 84s 338ms/step - loss: 0.3943 - accuracy: 0.8190 - val_loss: 0.4618 - val_accuracy: 0.7900
# Epoch 13/25
# 250/250 [==============================] - 87s 348ms/step - loss: 0.3735 - accuracy: 0.8301 - val_loss: 0.4905 - val_accuracy: 0.7835
# Epoch 14/25
# 250/250 [==============================] - 83s 333ms/step - loss: 0.3740 - accuracy: 0.8340 - val_loss: 0.4549 - val_accuracy: 0.8040
# Epoch 15/25
# 250/250 [==============================] - 84s 335ms/step - loss: 0.3485 - accuracy: 0.8446 - val_loss: 0.4750 - val_accuracy: 0.7885
# Epoch 16/25
# 250/250 [==============================] - 85s 342ms/step - loss: 0.3285 - accuracy: 0.8555 - val_loss: 0.4554 - val_accuracy: 0.8025
# Epoch 17/25
# 250/250 [==============================] - 83s 332ms/step - loss: 0.3116 - accuracy: 0.8591 - val_loss: 0.5510 - val_accuracy: 0.7560
# Epoch 18/25
# 250/250 [==============================] - 83s 331ms/step - loss: 0.3060 - accuracy: 0.8684 - val_loss: 0.4796 - val_accuracy: 0.7940
# Epoch 19/25
# 250/250 [==============================] - 83s 333ms/step - loss: 0.2915 - accuracy: 0.8761 - val_loss: 0.5198 - val_accuracy: 0.7915
# Epoch 20/25
# 250/250 [==============================] - 89s 355ms/step - loss: 0.2777 - accuracy: 0.8813 - val_loss: 0.4798 - val_accuracy: 0.8170
# Epoch 21/25
# 250/250 [==============================] - 83s 333ms/step - loss: 0.2635 - accuracy: 0.8941 - val_loss: 0.4803 - val_accuracy: 0.8045
# Epoch 22/25
# 250/250 [==============================] - 83s 333ms/step - loss: 0.2504 - accuracy: 0.8979 - val_loss: 0.5066 - val_accuracy: 0.7970
# Epoch 23/25
# 250/250 [==============================] - 85s 339ms/step - loss: 0.2396 - accuracy: 0.9001 - val_loss: 0.5041 - val_accuracy: 0.8025
# Epoch 24/25
# 250/250 [==============================] - 83s 333ms/step - loss: 0.2279 - accuracy: 0.9049 - val_loss: 0.5298 - val_accuracy: 0.8065
# Epoch 25/25
# 250/250 [==============================] - 83s 331ms/step - loss: 0.2132 - accuracy: 0.9137 - val_loss: 0.5350 - val_accuracy: 0.8065

# %% [markdown]
# ## Part 4 - Making a single prediction

# %%
import numpy as np
from keras.preprocessing import image
test_image = image.load_img('dataset/single_prediction/cat_or_dog_1.jpg', target_size = (64, 64))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)
result = cnn.predict(test_image)
training_set.class_indices
if result[0][0] == 1:
  prediction = 'dog'
else:
  prediction = 'cat'

# %%
print(prediction)
# Out:
# dog
